# %%
import pandas as pd
import pyrepseq as prs

# %% [markdown]
# ## Basic standardization

# %%
df = pd.DataFrame(
    data=[
        ["av26.1*1","CIVRAPGRADMRF","aj43*1","bv13*1","CASSYLPGQGDHYSNQPQHF","bj1.5*1","FLKEKGGL","b8","b2m"],
        ["TCRAV20*01","CAVPSGAGSYQLTF","TCRAJ28*01","TCRBV28S1*01","CASSLGQSGANVLTF","TCRBJ2S6*01","LQPFPQPELPYPQPQ","HLA-DQA1*05","HLA-DQB1*02"],
        ["unknown","unknown","unknown","TRBV7-2*01","CASSDWGSQNTLYF","TRBJ2-4*01","YMPYFFTLL","HLA-A*02","B2M"]
    ],
    columns=["TRAV","CDR3A","TRAJ","TRBV","CDR3B","TRBJ","Epitope","MHCA","MHCB"]
)
df
# Out:
#          TRAV           CDR3A        TRAJ          TRBV                 CDR3B  \
# 0    av26.1*1   CIVRAPGRADMRF      aj43*1        bv13*1  CASSYLPGQGDHYSNQPQHF
# 1  TCRAV20*01  CAVPSGAGSYQLTF  TCRAJ28*01  TCRBV28S1*01       CASSLGQSGANVLTF
# 2     unknown         unknown     unknown    TRBV7-2*01        CASSDWGSQNTLYF
#
#           TRBJ          Epitope         MHCA         MHCB
# 0      bj1.5*1         FLKEKGGL           b8          b2m
# 1  TCRBJ2S6*01  LQPFPQPELPYPQPQ  HLA-DQA1*05  HLA-DQB1*02
# 2   TRBJ2-4*01        YMPYFFTLL     HLA-A*02          B2M

# %%
prs.io.standardize_dataframe(df)
# Out:
# /home/yutanagano/Projects/pyrepseq/.venv/lib/python3.11/site-packages/tidytcells/aa/_standardize.py:80: UserWarning: Failed to standardize unknown: not a valid amino acid sequence.
#   warnings.warn(
# /home/yutanagano/Projects/pyrepseq/.venv/lib/python3.11/site-packages/tidytcells/_utils/warnings.py:12: UserWarning: Failed to standardize "unknown" for species homosapiens: unrecognised gene name. (best attempted fix: "TRUNKNOWN").
#   warn(warning_message)
#        TRAV           CDR3A    TRAJ     TRBV                 CDR3B     TRBJ  \
# 0  TRAV26-1   CIVRAPGRADMRF  TRAJ43   TRBV13  CASSYLPGQGDHYSNQPQHF  TRBJ1-5
# 1    TRAV20  CAVPSGAGSYQLTF  TRAJ28   TRBV28       CASSLGQSGANVLTF  TRBJ2-6
# 2      None            None    None  TRBV7-2        CASSDWGSQNTLYF  TRBJ2-4
#
#            Epitope      MHCA      MHCB
# 0         FLKEKGGL     HLA-B       B2M
# 1  LQPFPQPELPYPQPQ  HLA-DQA1  HLA-DQB1
# 2        YMPYFFTLL     HLA-A       B2M

# %% [markdown]
# ## Extra columns are allowed

# %%
extended_df = df.copy()
extended_df["clone_count"] = [1,2,3]
extended_df
# Out:
#          TRAV           CDR3A        TRAJ          TRBV                 CDR3B  \
# 0    av26.1*1   CIVRAPGRADMRF      aj43*1        bv13*1  CASSYLPGQGDHYSNQPQHF
# 1  TCRAV20*01  CAVPSGAGSYQLTF  TCRAJ28*01  TCRBV28S1*01       CASSLGQSGANVLTF
# 2     unknown         unknown     unknown    TRBV7-2*01        CASSDWGSQNTLYF
#
#           TRBJ          Epitope         MHCA         MHCB  clone_count
# 0      bj1.5*1         FLKEKGGL           b8          b2m            1
# 1  TCRBJ2S6*01  LQPFPQPELPYPQPQ  HLA-DQA1*05  HLA-DQB1*02            2
# 2   TRBJ2-4*01        YMPYFFTLL     HLA-A*02          B2M            3

# %%
prs.io.standardize_dataframe(extended_df)
# Out:
# /home/yutanagano/Projects/pyrepseq/.venv/lib/python3.11/site-packages/tidytcells/aa/_standardize.py:80: UserWarning: Failed to standardize unknown: not a valid amino acid sequence.
#   warnings.warn(
# /home/yutanagano/Projects/pyrepseq/.venv/lib/python3.11/site-packages/tidytcells/_utils/warnings.py:12: UserWarning: Failed to standardize "unknown" for species homosapiens: unrecognised gene name. (best attempted fix: "TRUNKNOWN").
#   warn(warning_message)
#        TRAV           CDR3A    TRAJ     TRBV                 CDR3B     TRBJ  \
# 0  TRAV26-1   CIVRAPGRADMRF  TRAJ43   TRBV13  CASSYLPGQGDHYSNQPQHF  TRBJ1-5
# 1    TRAV20  CAVPSGAGSYQLTF  TRAJ28   TRBV28       CASSLGQSGANVLTF  TRBJ2-6
# 2      None            None    None  TRBV7-2        CASSDWGSQNTLYF  TRBJ2-4
#
#            Epitope      MHCA      MHCB  clone_count
# 0         FLKEKGGL     HLA-B       B2M            1
# 1  LQPFPQPELPYPQPQ  HLA-DQA1  HLA-DQB1            2
# 2        YMPYFFTLL     HLA-A       B2M            3

# %% [markdown]
# ## Subsets of columns are allowed

# %%
beta_only_df = df.copy()
beta_only_df = beta_only_df[["TRBV","CDR3B","TRBJ"]]
beta_only_df
# Out:
#            TRBV                 CDR3B         TRBJ
# 0        bv13*1  CASSYLPGQGDHYSNQPQHF      bj1.5*1
# 1  TCRBV28S1*01       CASSLGQSGANVLTF  TCRBJ2S6*01
# 2    TRBV7-2*01        CASSDWGSQNTLYF   TRBJ2-4*01

# %%
prs.io.standardize_dataframe(beta_only_df)
# Out:
#       TRBV                 CDR3B     TRBJ
# 0   TRBV13  CASSYLPGQGDHYSNQPQHF  TRBJ1-5
# 1   TRBV28       CASSLGQSGANVLTF  TRBJ2-6
# 2  TRBV7-2        CASSDWGSQNTLYF  TRBJ2-4

# %% [markdown]
# ## Rename columns with col_mapper

# %%
beta_only_misnamed = beta_only_df.copy()
beta_only_misnamed.columns = ["foo", "bar", "baz"]
beta_only_misnamed
# Out:
#             foo                   bar          baz
# 0        bv13*1  CASSYLPGQGDHYSNQPQHF      bj1.5*1
# 1  TCRBV28S1*01       CASSLGQSGANVLTF  TCRBJ2S6*01
# 2    TRBV7-2*01        CASSDWGSQNTLYF   TRBJ2-4*01

# %%
col_mapper = {
    "foo": "TRBV",
    "bar": "CDR3B",
    "baz": "TRBJ"
}
prs.io.standardize_dataframe(beta_only_misnamed, col_mapper=col_mapper)
# Out:
#       TRBV                 CDR3B     TRBJ
# 0   TRBV13  CASSYLPGQGDHYSNQPQHF  TRBJ1-5
# 1   TRBV28       CASSLGQSGANVLTF  TRBJ2-6
# 2  TRBV7-2        CASSDWGSQNTLYF  TRBJ2-4
